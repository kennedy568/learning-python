# %%
import pandas as pd
import nltk
df = pd.read_csv('NLP ML 2  - Sheet1.csv')
df.head(50)
# Out:
#                                                  word    Target
# 0   Now the hottest stock in the market is $CHL Ch...      spam
# 1   We have just announced a fun free posting cont...      spam
# 2   Your monthly review is ready. We crunch the nu...  not_spam
# 3   You received this email because because you're...      spam
# 4   Bismart posted in Friends Who Like Association...  not_spam
# 5   hi Njau, I would suggest that you join any or ...  not_spam
# 6   Dear KENNEDY NGANGA,    lease find attached yo...  not_spam
# 7                  Gichure Anthony added a new photo.      spam
# 8                   Charita Chacha added a new photo.      spam
# 9   New Year’s learning sale for courses from US$9...  not_spam
# 10  Hi Kennedy Njau,\n\nYour login password has be...  not_spam
# 11  Hi Kennedy Njau,\n\nA password reset for your ...  not_spam
# 12  The Great Reset, Part I: Reduced Expectations ...      spam
# 13  Adopting A Gold Standard Would Promote Fiscal ...      spam
# 14  Symbols... Of Subtle Oppression": Virginia Jud...      spam
# 15  We heard that you lost your GitHub password. S...  not_spam
# 16  Hi KENNEDY2015,\nThank you for joining edX! As...      spam
# 17  \njohn kamau <kkamaujohn@gmail.com>\nAttachmen...  not_spam
# 18  You received this mail because Nelly Njau shar...      spam
# 19  gone through your work, that was also very gre...  not_spam
# 20  This is really good, I especially liked how yo...  not_spam
# 21  Recently I asked Alex to do a household survey...  not_spam
# 22  Hi,\nWe have just announced a fun free posting...      spam
# 23  Dear ken,\nNow the hottest stock in the market...      spam
# 24  Dear ken,\nNow the hottest stock in the market...      spam
# 25  Dear ken,\nNow the hottest stock in the market...      spam
# 26                Anncathy Wairimu posted an update..      spam
# 27  Simo Muchai posted an update.\nDecember 20 at ...      spam
# 28  Dear ken,\nSome topics you might have missed.\...      spam
# 29  please try this by tomorrow, its a simple mach...  not_spam
# 30  Dear Taxpayer,\n\nA tax refund is a reimbursem...  not_spam
# 31  Dear Taxpayer,\nWhen applying for a tax refund...  not_spam
# 32  Dear KENNEDY NGANGA,\nPlease find attached you...  not_spam
# 33  A very special thank you to you and your team ...  not_spam
# 34  Hi Njau\n\nI would suggest that you join any o...  not_spam
# 35  Hi Kennedy Njau,\nYour login password has been...  not_spam
# 36  2020 F1 Esports Pro Series\nRound Four ReportR...      spam
# 37   \nNjau, join groups to connect with people wh...      spam
# 38  Njau, join groups to connect with people who s...      spam
# 39  Manchester United Fans Around The World\nBecau...      spam
# 40  KABETE WANGIGE GROUP\nArcbishop and 52 friends...      spam
# 41  MAN UNITED TRUE FANS\nBecause you viewed Old T...      spam
# 42                Manchester United Daily Update News      spam
# 43       OLD TRAFFORD, MANCHESTER UNITED FANS & NEWS✅      spam
# 44  Dear Taxpayer,\nThe Finance Act 2020 introduce...  not_spam
# 45  75% Off Individual Subscription\nSave Now\nHea...      spam
# 46  Hi Everyone!\n\nAs we head into 2021 we're hav...      spam
# 47  Hi Everyone!\n\nAs we head into 2021 we're hav...  not_spam
# 48  Dear KENNEDY NGANGA, \nPlease find attached yo...  not_spam

# %%
import nltk
from string import punctuation
punc = list(punctuation)
stop = nltk.corpus.stopwords.words('english')+punc
def cleaner(words):
    words=words.lower()
    words= nltk.word_tokenize(words)
    words=[word for word in words if not word in stop]
    return ' '.join(words)
df['clean_words']=list(map(cleaner,df.word))
df.head()
# Out:
#                                                 word    Target  \
# 0  Now the hottest stock in the market is $CHL Ch...      spam
# 1  We have just announced a fun free posting cont...      spam
# 2  Your monthly review is ready. We crunch the nu...  not_spam
# 3  You received this email because because you're...      spam
# 4  Bismart posted in Friends Who Like Association...  not_spam
#
#                                          clean_words
# 0  hottest stock market chl china mobile limited ...
# 1  announced fun free posting contest january two...
# 2  monthly review ready crunch numbers help under...
# 3  received email 're participating 'uber nairobi...
# 4  bismart posted friends like association kenya ...

# %%
from sklearn.feature_extraction.text import CountVectorizer
vect = CountVectorizer()
x = vect.fit_transform(df.clean_words)
y = df.Target
from sklearn.model_selection  import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.25,random_state =10)
from sklearn.naive_bayes import MultinomialNB
model = MultinomialNB()
model.fit(x_train,y_train)
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %%
from sklearn.metrics import accuracy_score
pred = model.predict(x_test)
accuracy_score(pred,y_test)
# Out:
# 0.7692307692307693
