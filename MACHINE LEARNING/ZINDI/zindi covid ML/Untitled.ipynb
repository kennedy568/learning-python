# %%
import pandas as pd
import numpy as np
import nltk
df = pd.read_csv('updated_train.csv')
df.head(50)
# Out:
#           ID                                               text  target
# 0    train_0            The bitcoin halving is cancelled due to       1
# 1    train_1  MercyOfAllah In good times wrapped in its gran...       0
# 2    train_2  266 Days No Digital India No Murder of e learn...       1
# 3    train_3  India is likely to run out of the remaining RN...       1
# 4    train_4  In these tough times the best way to grow is t...       0
# 5    train_5  FIFA has proposed allowing teams to make up to...       0
# 6    train_6  Lovers of sports especially do you know why so...       0
# 7    train_7                     ig he kinda cute sometimes smh       0
# 8    train_8  Frontline health workers are critical in the f...       1
# 9    train_9  Contact centers are getting overwhelmed with c...       0
# 10  train_10  Maybe one of the distinguishing features of a ...       1
# 11  train_11  The BEST REWARD for any Human Being on earth n...       0
# 12  train_12  Article New tool on how to adapt our health me...       1
# 13  train_13  Asks Chief Judge to Free Prisoners Due to  Thr...       1
# 14  train_14  It is with great sadness we announce that phar...       1
# 15  train_15  Is anything more damning of this Tory governme...       1
# 16  train_16  Can someone clarify for me why we are reportin...       1
# 17  train_17  The mayor of Osaka Japan s third largest city ...       1
# 18  train_18  The is a labor of love for Check out how he go...       0
# 19  train_19  An EU report about Chinese and Russian disinfo...       1
# 20  train_20                  Bayelsa records its index case of       1
# 21  train_21  Are bureaucrats taking advantage of PMs total ...       1
# 22  train_22  O ye who believe fasting is prescribed for you...       0
# 23  train_23  To bake more fun for you in here we are with H...       1
# 24  train_24  I am praying that abounding joy will undoubted...       0
# 25  train_25  since it s the beginning of Ramadan for our fe...       0
# 26  train_26    Graham is like a cat Gets the zoomies sometimes       0
# 27  train_27  Dry yer eyes mate WM incompetence has given us...       1
# 28  train_28  Make Ramadan Greeting Card At Home Watch Full ...       0
# 29  train_29  Thx a lot for the feedback I ll stress test it...       0
# 30  train_30  Jenrick urges house builders to reopen sites a...       1
# 31  train_31  Ramadan period drama with Jewish characters st...       0
# 32  train_32  com That Mufti is drunk Plus is Ramadan He sho...       0
# 33  train_33  I spoke to about the Industry and how he would...       1
# 34  train_34  The live blog is reporting Sir Patrick Vallanc...       1
# 35  train_35  What happens when religious eating habits conf...       0
# 36  train_36  Real fake deaths this is the kind of lies doct...       1
# 37  train_37  50 in 50 Baseball returns to Milwaukee after f...       0
# 38  train_38  Pls don t forget to put her in your prayers th...       0
# 39  train_39  He was warned of the danger the beginning of J...       1
# 40  train_40  you know france has mcdonalds and fast food to...       0
# 41  train_41                      Machine learning is a success       0
# 42  train_42  This series of tweets and the frightening gap ...       1
# 43  train_43  Dear tweeps My uncle called me today by his ow...       0
# 44  train_44  It s National Volunteer Appreciation Month a b...       0
# 45  train_45  Four weeks ago on March 26 there were 938 conf...       1
# 46  train_46         Padres prospect countdown No 2 Luis Pati o       0
# 47  train_47  blackstock Guia s family has set up this in he...       1
# 48  train_48            NEW BLOG POST Recording at Home During        1
# 49  train_49  Hello again my birthday is in 29 days and my w...       0

# %%
#df.isnull().value_counts()

# %%
from string import punctuation
punc = list(punctuation)
stop = nltk.corpus.stopwords.words('english')+punc
def cleaner(words):
    words=words.lower()
    words= nltk.word_tokenize(words)
    words=[word for word in words if not word in stop]
    return ' '.join(words)
df['clean_text']=list(map(cleaner,df.text))
df.head()
# Out:
#         ID                                               text  target  \
# 0  train_0            The bitcoin halving is cancelled due to       1
# 1  train_1  MercyOfAllah In good times wrapped in its gran...       0
# 2  train_2  266 Days No Digital India No Murder of e learn...       1
# 3  train_3  India is likely to run out of the remaining RN...       1
# 4  train_4  In these tough times the best way to grow is t...       0
#
#                                           clean_text
# 0                      bitcoin halving cancelled due
# 1  mercyofallah good times wrapped granular detai...
# 2  266 days digital india murder e learning 2g on...
# 3  india likely run remaining rna kits essential ...
# 4  tough times best way grow learn case teach hel...

# %%
from sklearn.feature_extraction.text import CountVectorizer
vect = CountVectorizer()
x = vect.fit_transform(df.clean_text)
y = df.target
from sklearn.model_selection  import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.1,random_state =10)
from sklearn.naive_bayes import MultinomialNB
model = MultinomialNB()
model.fit(x_train,y_train)
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %%
from sklearn.metrics import accuracy_score
pred = model.predict(x_test)
accuracy_score(pred,y_test)
# Out:
# 0.9073724007561437
