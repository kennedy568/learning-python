# %%
import pandas as pd
import os
os.listdir()
df = pd.read_csv('titanic.csv')

# %%
# !dir
# Out:
# titanic.csv  Titanic\ Dataset.ipynb

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df.head(10)
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                             Mr. Owen Harris Braund
# 1         1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2         1       3                              Miss. Laina Heikkinen
# 3         1       1        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 4         0       3                            Mr. William Henry Allen
# 5         0       3                                    Mr. James Moran
# 6         0       1                             Mr. Timothy J McCarthy
# 7         0       3                      Master. Gosta Leonard Palsson
# 8         1       3   Mrs. Oscar W (Elisabeth Vilhelmina Berg) Johnson
# 9         1       2                 Mrs. Nicholas (Adele Achem) Nasser
#
#       Sex   Age  Siblings/Spouses Aboard  Parents/Children Aboard     Fare
# 0    male  22.0                        1                        0   7.2500
# ...

# %%
df.tail(10)
# Out:
#      Survived  Pclass                                 Name     Sex   Age  \
# 877         0       3                    Mr. Johann Markun    male  33.0
# 878         0       3          Miss. Gerda Ulrika Dahlberg  female  22.0
# 879         0       2         Mr. Frederick James Banfield    male  28.0
# 880         0       3                Mr. Henry Jr Sutehall    male  25.0
# 881         0       3  Mrs. William (Margaret Norton) Rice  female  39.0
# 882         0       2                 Rev. Juozas Montvila    male  27.0
# 883         1       1          Miss. Margaret Edith Graham  female  19.0
# 884         0       3       Miss. Catherine Helen Johnston  female   7.0
# 885         1       1                 Mr. Karl Howell Behr    male  26.0
# 886         0       3                   Mr. Patrick Dooley    male  32.0
#
#      Siblings/Spouses Aboard  Parents/Children Aboard     Fare
# 877                        0                        0   7.8958
# ...

# %%
df.rename(columns = {'Siblings/Spouses Aboard':'SSA'}, inplace = True)

# %%
df.rename(columns = {'Parents/Children Aboard':'PCA'}, inplace = True)

# %%
df['FamilySize'] = df['SSA'] + df['PCA']

# %%
df['Total_FamilySize'] = df['SSA'] + df['PCA']+(int(1))

# %%
 empty =[]
for i in df['Survived']:
    #print(i)
    if i >0:
            empty.append(False)
    else:
            empty.append(True)

df['survived'] =  empty

# %%
df.head(13)
# Out:
#     Survived  Pclass                                               Name  \
# 0          0       3                             Mr. Owen Harris Braund
# 1          1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2          1       3                              Miss. Laina Heikkinen
# 3          1       1        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 4          0       3                            Mr. William Henry Allen
# 5          0       3                                    Mr. James Moran
# 6          0       1                             Mr. Timothy J McCarthy
# 7          0       3                      Master. Gosta Leonard Palsson
# 8          1       3   Mrs. Oscar W (Elisabeth Vilhelmina Berg) Johnson
# 9          1       2                 Mrs. Nicholas (Adele Achem) Nasser
# 10         1       3                     Miss. Marguerite Rut Sandstrom
# 11         1       1                            Miss. Elizabeth Bonnell
# ...

# %%
df.isnull().sum()
# Out:
# Survived            0
# Pclass              0
# Name                0
# Sex                 0
# Age                 0
# SSA                 0
# PCA                 0
# Fare                0
# FamilySize          0
# Total_FamilySize    0
# survived            0
# dtype: int64

# %%
df.shape
# Out:
# (887, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 887 entries, 0 to 886
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Survived          887 non-null    int64
#  1   Pclass            887 non-null    int64
#  2   Name              887 non-null    object
#  3   Sex               887 non-null    object
#  4   Age               887 non-null    float64
#  5   SSA               887 non-null    int64
#  6   PCA               887 non-null    int64
#  7   Fare              887 non-null    float64
#  8   FamilySize        887 non-null    int64
#  9   Total_FamilySize  887 non-null    int64
#  10  survived          887 non-null    bool
# dtypes: bool(1), float64(2), int64(6), object(2)
# memory usage: 70.3+ KB

# %%
df.describe()
# Out:
#          Survived      Pclass         Age         SSA         PCA       Fare  \
# count  887.000000  887.000000  887.000000  887.000000  887.000000  887.00000
# mean     0.385569    2.305524   29.471443    0.525366    0.383315   32.30542
# std      0.487004    0.836662   14.121908    1.104669    0.807466   49.78204
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.00000
# 25%      0.000000    2.000000   20.250000    0.000000    0.000000    7.92500
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.45420
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.13750
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.32920
#
#        FamilySize  Total_FamilySize
# count  887.000000        887.000000
# mean     0.908681          1.908681
# std      1.615949          1.615949
# min      0.000000          1.000000
# 25%      0.000000          1.000000
# 50%      0.000000          1.000000
# ...

# %%
# how many people survived?

empty = []
for i in zip(df['Total_FamilySize'],df['survived']):
    #print(i)
    if i[1]==True:
        empty.append(i[0],)

df['Total_survived'] = pd.DataFrame(empty) 

df['Total_survived'].sum()
# Out:
# 1030.0

# %%
# how many people died?

non_survivors = df[df.survived==False]

empty = []
for i in zip(df['Total_FamilySize'],df['survived']):
    #print(i)
    if i[1]==False:
        empty.append(i[0],)

df['Died'] = pd.DataFrame(empty) 

df['Died'].sum()
# Out:
# 663.0

# %%
df.head(15)
# Out:
#     Survived  Pclass                                               Name  \
# 0          0       3                             Mr. Owen Harris Braund
# 1          1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2          1       3                              Miss. Laina Heikkinen
# 3          1       1        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 4          0       3                            Mr. William Henry Allen
# 5          0       3                                    Mr. James Moran
# 6          0       1                             Mr. Timothy J McCarthy
# 7          0       3                      Master. Gosta Leonard Palsson
# 8          1       3   Mrs. Oscar W (Elisabeth Vilhelmina Berg) Johnson
# 9          1       2                 Mrs. Nicholas (Adele Achem) Nasser
# 10         1       3                     Miss. Marguerite Rut Sandstrom
# 11         1       1                            Miss. Elizabeth Bonnell
# ...

# %%
# how many passangers were in the data?

#df.shape
df['Total_FamilySize'].sum()
# Out:
# 1693

# %%
passengers = len(df)

survivors =df[df.survived==True]

survivors


df['Total_FamilySize']
# Out:
# 0      2
# 1      2
# 2      1
# 3      2
# 4      1
#       ..
# 882    1
# 883    1
# 884    4
# 885    1
# 886    1
# Name: Total_FamilySize, Length: 887, dtype: int64

# %%
# How many females survived
empty = []
for i in zip(df['Total_survived'],df['Sex']):
    #print(i)
    if i[1]== 'female':
        empty.append(i[0],)

df['Female_Survivors'] = pd.DataFrame(empty) 

df['Female_Survivors'].sum()
# Out:
# 410.0

# %%
# how many males  survived 

empty = []
for i in zip(df['Total_survived'],df['Sex']):
    #print(i)
    if i[1]== 'male':
        empty.append(i[0],)

df['Male_Survivors'] = pd.DataFrame(empty) 

df['Male_Survivors'].sum()
# Out:
# 620.0

# %%
df.head(2)
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                             Mr. Owen Harris Braund
# 1         1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
#
#       Sex   Age  SSA  PCA     Fare  FamilySize  Total_FamilySize  survived  \
# 0    male  22.0    1    0   7.2500           1                 2      True
# 1  female  38.0    1    0  71.2833           1                 2     False
#
#    Total_survived  Died  Female_Survivors  Male_Survivors
# 0             2.0   2.0               1.0             2.0
# 1             1.0   1.0               1.0             5.0

# %%
# how many people from each class survived - PClass

table = pd.crosstab(df['Total_survived'],df['Pclass']).sum()
print (table)
# Out:
# Pclass
# 1    131
# 2    115
# 3    299
# dtype: int64

# %%
# what was the correlation between having children aboard and surviving? - use a correlation

df[['PCA','Total_survived']].corr()
# Out:
#                      PCA  Total_survived
# PCA             1.000000        0.002447
# Total_survived  0.002447        1.000000

# %%
# what was the correlation between having Siblings/spouses aboard and surviving?


df[['SSA','Total_survived']].corr()
# Out:
#                      SSA  Total_survived
# SSA             1.000000       -0.003016
# Total_survived -0.003016        1.000000

# %%
# what was the correlation between fare paid and survival?
df[['Fare','Total_survived']].corr()
# Out:
#                     Fare  Total_survived
# Fare            1.000000        0.006643
# Total_survived  0.006643        1.000000

# %%
# what was the median age of those that survived?


df.groupby('Age').Total_survived.median()
# Out:
# Age
# 0.42     NaN
# 0.67     NaN
# 0.75     1.0
# 0.83     2.0
# 0.92     1.0
#         ...
# 70.00    NaN
# 70.50    3.0
# 71.00    1.0
# 74.00    NaN
# 80.00    NaN
# Name: Total_survived, Length: 89, dtype: float64

# %%
# what was the mean fare paid of those that survived?

df.groupby('Fare').Survived.mean()
# Out:
# Fare
# 0.0000      0.066667
# 4.0125      0.000000
# 5.0000      0.000000
# 6.2375      0.000000
# 6.4375      0.000000
#               ...
# 227.5250    0.750000
# 247.5208    0.500000
# 262.3750    1.000000
# 263.0000    0.500000
# 512.3292    1.000000
# Name: Survived, Length: 248, dtype: float64

# %%
df.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                             Mr. Owen Harris Braund
# 1         1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2         1       3                              Miss. Laina Heikkinen
# 3         1       1        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 4         0       3                            Mr. William Henry Allen
#
#       Sex   Age  Siblings/Spouses Aboard  Parents/Children Aboard     Fare
# 0    male  22.0                        1                        0   7.2500
# 1  female  38.0                        1                        0  71.2833
# 2  female  26.0                        0                        0   7.9250
# 3  female  35.0                        1                        0  53.1000
# 4    male  35.0                        0                        0   8.0500

# %%
# what was the mean fare paid of those that survived?

df.>4.9

# %% [markdown]
# # PLots

# %%
df.head(2)
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                             Mr. Owen Harris Braund
# 1         1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
#
#       Sex   Age  Siblings/Spouses Aboard  Parents/Children Aboard     Fare
# 0    male  22.0                        1                        0   7.2500
# 1  female  38.0                        1                        0  71.2833

# %%
# make a histogram of the fare, add a density plot and comment on the type of distribution

import matplotlib.pyplot as plt
plt.pie(df.Sex.value_counts())
# Out:
# ([<matplotlib.patches.Wedge at 0x7f876e0b2090>,
# ...
#  [Text(-0.48702712164056955, 0.9863085636789849, ''),
#   Text(0.4870272139854391, -0.9863085180802108, '')])

# %%
# make a pie chart of the survived class use the example below to get some idea
import matplotlib.pyplot as plt
plt.pie(df.Pclass.value_counts())
# Out:
# ([<matplotlib.patches.Wedge at 0x7fcdc6c8a3d0>,
# ...
#  [Text(-0.168806221998705, 1.086970312112766, ''),
#   Text(-0.5250745078827247, -0.9665902757485794, ''),
#   Text(0.8745627464170572, -0.6671881313238825, '')])

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# make a barchart of the survived class ( coment on the distribution)
sns.barplot(x='Pclass', y='Survived', data=df)

# %% [markdown]
# # Trivia

# %%
#what was the most common first name in the dataset.

print((df["Name"].unique()))
# Out:
# ['Mr. Owen Harris Braund'
#  'Mrs. John Bradley (Florence Briggs Thayer) Cumings'
#  'Miss. Laina Heikkinen' 'Mrs. Jacques Heath (Lily May Peel) Futrelle'
#  'Mr. William Henry Allen' 'Mr. James Moran' 'Mr. Timothy J McCarthy'
#  'Master. Gosta Leonard Palsson'
#  'Mrs. Oscar W (Elisabeth Vilhelmina Berg) Johnson'
#  'Mrs. Nicholas (Adele Achem) Nasser' 'Miss. Marguerite Rut Sandstrom'
#  'Miss. Elizabeth Bonnell' 'Mr. William Henry Saundercock'
#  'Mr. Anders Johan Andersson' 'Miss. Hulda Amanda Adolfina Vestrom'
#  'Mrs. (Mary D Kingcome) Hewlett' 'Master. Eugene Rice'
#  'Mr. Charles Eugene Williams'
#  'Mrs. Julius (Emelia Maria Vandemoortele) Vander Planke'
#  'Mrs. Fatima Masselmani' 'Mr. Joseph J Fynney' 'Mr. Lawrence Beesley'
#  'Miss. Anna McGowan' 'Mr. William Thompson Sloper'
#  'Miss. Torborg Danira Palsson'
#  'Mrs. Carl Oscar (Selma Augusta Emilia Johansson) Asplund'
#  'Mr. Farred Chehab Emir' 'Mr. Charles Alexander Fortune'
# ...

# %%
# Make a barplot of the 20 most common last names
